# %% [markdown]
# # Spotify: Working with Playlists

# %%
# import dependencies:
from apis import spotify
from pprint import pprint
import pandas as pd
from IPython.display import HTML

from IPython.core.display import HTML

# some formatting:
HTML(spotify.get_jupyter_styling())
# Out:
#         <style>
#             .rendered_html img {
#                 display: inline-block;
#                 vertical-align: baseline;
#                 max-width: 200px !important;
#                 margin-right: 20px !important;
#             }
#             .rendered_html td, .rendered_html th { text-align: left !important; }
#         </style>

# %%
# Let's understand our options by using the help function:
# help(spotify)

# %% [markdown]
# ## 1. Get playlists by search term

# %%
# search_term = input('Which artist do you want to listen to? ')
search_term = 'bob dylan'
playlists = spotify.get_playlists(search_term)

# 1. Uncomment below to see the returned data:
# pprint(playlists)

# 2. pandas doesn't gracefully handle heirarchal data (uncomment below to see what I mean)
# df = pd.DataFrame(tracks)
# df.head(3)

# 3. Format data and display in Pandas:
playlists = spotify.flatten_for_pandas(playlists)
df = pd.DataFrame(playlists).set_index('num')
df.head(8)
# Out:
#                          id                     name   owner_display_name  \
# num
# 1    37i9dQZF1DX8f6VxHEcGCN        This Is Bob Dylan              Spotify
# 2    37i9dQZF1DX0q1RHoDiZBg       Bob Dylan: Covered              Spotify
# 3    1h7X42UUawuKy1ZbY3qkgA   Bob Dylan - Top Tracks    Legacy Recordings
# 4    2SSewe0qP7eUEfelwi5HXd  Bob Dylan Greatest Hits               zeyank
# 5    3kkw0IFusUUsjrYl2d85FY         Bob Dylan Covers               manacc
# 6    15tjyXYtktOUlUnjMt7W3E        Best of Bob Dylan         Genny Liebes
# 7    06inki51KH8H12nXhSbX8M                Bob Dylan  Filtr Legacy Sweden
# 8    1ByNtt7Hj3FvLxlsbgXKyR         Sara – Bob Dylan         jaimefisio21
#
#              owner_id                                          share_url
# num
# 1             spotify  https://open.spotify.com/playlist/37i9dQZF1DX8...
# 2             spotify  https://open.spotify.com/playlist/37i9dQZF1DX0...
# 3    legacyrecordings  https://open.spotify.com/playlist/1h7X42UUawuK...
# 4              zeyank  https://open.spotify.com/playlist/2SSewe0qP7eU...
# 5              manacc  https://open.spotify.com/playlist/3kkw0IFusUUs...
# 6          1251365134  https://open.spotify.com/playlist/15tjyXYtktOU...
# 7        legacysweden  https://open.spotify.com/playlist/06inki51KH8H...
# 8        jaimefisio21  https://open.spotify.com/playlist/1ByNtt7Hj3Fv...

# %% [markdown]
# ## 2. Ask the user which artist they'd like to listen to

# %%
# artist_num = input('What artist would you like to listen to (1-10)? ')
playlist_num = 2
playlist_index = int(playlist_num) - 1
selected_playlist = playlists[playlist_index]

tracks = spotify.get_tracks_by_playlist(selected_playlist['id'], simplify=True)
# pprint(tracks)
tracks = spotify.flatten_for_pandas(tracks)
df_tracks = pd.DataFrame(tracks).set_index('num')
df_tracks[['artist_name', 'name', 'album_name', 'album_image_url']].head(5)
# Out:
#           artist_name                                               name  \
# num
# 1    Rhiannon Giddens              Forever Young - From NBC's Parenthood
# 2       Laura Marling                         A Hard Rain's A-Gonna Fall
# 3        Eddie Berman                               Like a Rolling Stone
# 4        Jeff Buckley                                  Just Like a Woman
# 5     Various Artists  The Times They Are a-Changin' - Live at Madiso...
#
#                                             album_name  \
# num
# 1                Forever Young (From NBC's Parenthood)
# 2                           A Hard Rain's A-Gonna Fall
# 3                                           Polyhymnia
# 4                                            You and I
# 5    Bob Dylan - 30th Anniversary Concert Celebrati...
#
#                                        album_image_url
# num
# 1    https://i.scdn.co/image/73a8c4050ef9f04770eb37...
# 2    https://i.scdn.co/image/7371bfb49a1e9dc0d3af48...
# 3    https://i.scdn.co/image/baf4d16a65d5a63e82bbaa...
# 4    https://i.scdn.co/image/227560893358afa85bb93c...
# 5    https://i.scdn.co/image/084bfb84b86c43b4a647f4...

# %%
# if you wanted to email these tracks to someone...
html_table = spotify.get_formatted_tracklist_table_html(tracks)
display(HTML(html_table))
# Out:
# <table style="border-collapse: collapse; border: solid 1px #CCC;">
#   <thead>
#     <tr >
#       <th>name</th>
#       <th>album_image_url_small</th>
#       <th>artist_name</th>
#       <th>album_name</th>
#       <th>share_url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="border: solid 1px #CCC;">
#       <td>Forever Young - From NBC's Parenthood</td>
#       <td><img src="https://i.scdn.co/image/b77b5db53ebb076dc68e0584d417d6f7b6a20d1a" /></td>
#       <td>Rhiannon Giddens</td>
#       <td>Forever Young (From NBC's Parenthood)</td>
#       <td><a href="https://open.spotify.com/track/0QYgtwYCftkAqunXmvkZtr" target="_blank">https://open.spotify.com/track/0QYgtwYCftkAqunXmvkZtr</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>A Hard Rain's A-Gonna Fall</td>
#       <td><img src="https://i.scdn.co/image/bae8678564035088cd1b55588f6697fecf3e9f84" /></td>
#       <td>Laura Marling</td>
#       <td>A Hard Rain's A-Gonna Fall</td>
#       <td><a href="https://open.spotify.com/track/4bVP0pq7lIhDQBXSkejNS4" target="_blank">https://open.spotify.com/track/4bVP0pq7lIhDQBXSkejNS4</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>Like a Rolling Stone</td>
#       <td><img src="https://i.scdn.co/image/5b0212dc300b12e7c3f32d2eaf25049d3dcde412" /></td>
#       <td>Eddie Berman</td>
#       <td>Polyhymnia</td>
#       <td><a href="https://open.spotify.com/track/3Bf9nJGn3UQmHv8Ngx3f8S" target="_blank">https://open.spotify.com/track/3Bf9nJGn3UQmHv8Ngx3f8S</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>Just Like a Woman</td>
#       <td><img src="https://i.scdn.co/image/aabfb0ca43bb734f648c40fb8823221954fb05cc" /></td>
#       <td>Jeff Buckley</td>
#       <td>You and I</td>
#       <td><a href="https://open.spotify.com/track/2Jo0Yp0OcxlDyLxVGQazYC" target="_blank">https://open.spotify.com/track/2Jo0Yp0OcxlDyLxVGQazYC</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>The Times They Are a-Changin' - Live at Madison Square Garden, New York, NY - October 1992</td>
#       <td><img src="https://i.scdn.co/image/d4ee1e307f89f2884e4083dc2b314f47405035b1" /></td>
#       <td>Various Artists</td>
#       <td>Bob Dylan - 30th Anniversary Concert Celebration [(Deluxe Edition) [Remastered]]</td>
#       <td><a href="https://open.spotify.com/track/0IvdJ0V3Sl6ClrmJLrGEUV" target="_blank">https://open.spotify.com/track/0IvdJ0V3Sl6ClrmJLrGEUV</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>Masters of War</td>
#       <td><img src="https://i.scdn.co/image/b959188afea62b3c5c9c7336dd7d5b80ad5f10b2" /></td>
#       <td>Various Artists</td>
#       <td>The People Speak</td>
#     <tr style="border: solid 1px #CCC;">
#       <td>Farewell Angelina - Bonus Track</td>
#       <td><img src="https://i.scdn.co/image/868999bc3b26e8008a5a45a4f8f160106d846a09" /></td>
#       <td>Various Artists</td>
#       <td>Subterranean Homesick Blues: A Tribute to Bob Dylan's 'Bringing It All Back Home'</td>
#       <td><a href="https://open.spotify.com/track/1oe5WAmL6R23auAK49cBZZ" target="_blank">https://open.spotify.com/track/1oe5WAmL6R23auAK49cBZZ</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>Knockin' On Heaven's Door</td>
#       <td><img src="https://i.scdn.co/image/b7d432cb922154cceb0e1495f6432f6c7f6cfde1" /></td>
#       <td>Original Soundtrack</td>
#       <td>I'm Not There (Music From The Motion Picture)</td>
#       <td><a href="https://open.spotify.com/track/2GSFSTeDDRw9WXpc63T6up" target="_blank">https://open.spotify.com/track/2GSFSTeDDRw9WXpc63T6up</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>Simple Twist Of Fate</td>
#       <td><img src="https://i.scdn.co/image/48300881de58ed952f37563f84178905c4c24949" /></td>
#       <td>Sarah Jarosz</td>
#       <td>Build Me Up From Bones</td>
#       <td><a href="https://open.spotify.com/track/7bKJtDh41HViUzl3Hthc3U" target="_blank">https://open.spotify.com/track/7bKJtDh41HViUzl3Hthc3U</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>Spanish Mary</td>
#       <td><img src="https://i.scdn.co/image/4b03298f1e8cf10a59e7975940642444f48e6e5e" /></td>
#       <td>The New Basement Tapes</td>
#       <td>Lost On The River (Deluxe)</td>
#       <td><a href="https://open.spotify.com/track/7KbuK70PwKK722BvMXvfqB" target="_blank">https://open.spotify.com/track/7KbuK70PwKK722BvMXvfqB</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>You're Gonna Make Me Lonesome When You Go</td>
#       <td><img src="https://i.scdn.co/image/e3eaf0f32db0aaf697df63dba347fd2cfd02c32e" /></td>
#       <td>Various Artists</td>
#       <td>Chimes Of Freedom: The Songs Of Bob Dylan Honoring 50 Years Of Amnesty International</td>
#       <td><a href="https://open.spotify.com/track/4elbVXqYcmvakKQKpJ0ZUP" target="_blank">https://open.spotify.com/track/4elbVXqYcmvakKQKpJ0ZUP</a></td>
#     </tr>
#     <tr style="border: solid 1px #CCC;">
#       <td>One More Cup of Coffee - Recorded at Spotify Studios NYC</td>
#       <td><i

# %% [markdown]
# ## 3. Listen to playlist

# %%
playlist_player = spotify.get_playlist_player_html(selected_playlist['id'])
# print('This is what the HTML embed code looks like:\n', track_player)
print(playlist_player)
display(HTML(playlist_player))
# Out:
#     <iframe src="https://open.spotify.com/embed/playlist/37i9dQZF1DX0q1RHoDiZBg"
#         width="400" height="280" frameborder="0" allowtransparency="true"
#         allow="encrypted-media">
#     </iframe>
#     <iframe src="https://open.spotify.com/embed/playlist/37i9dQZF1DX0q1RHoDiZBg"
#         width="400" height="280" frameborder="0" allowtransparency="true"
#         allow="encrypted-media">
#     </iframe>

# %% [markdown]
# ## 4. Get other playlists from this user

# %%
user_id = selected_playlist['owner_id']

print('Getting {user_id}\'s playlists...'.format(user_id=user_id))
playlists = spotify.get_playlists_by_user(user_id)
playlists = spotify.flatten_for_pandas(playlists)
df = pd.DataFrame(playlists)
df.head(8)
