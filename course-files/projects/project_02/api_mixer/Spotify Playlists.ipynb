# %% [markdown]
# # Spotify: Working with Playlists

# %%
# import dependencies:
from apis import spotify
from pprint import pprint
import pandas as pd
from IPython.display import HTML

from IPython.core.display import HTML

# some formatting:
HTML(spotify.get_jupyter_styling())
# Out:
#             <style>
#                 .rendered_html img {
#                     display: inline-block;
#                     vertical-align: baseline;
#                     max-width: 200px !important;
#                     margin-right: 20px !important;
#                 }
#                 .rendered_html td, .rendered_html th { text-align: left !important; }
#             </style>

# %%
# Let's understand our options by using the help function:
# help(spotify)

# %% [markdown]
# ## 1. Get playlists by search term

# %%
# search_term = input('Which artist do you want to listen to? ')
search_term = 'cut copy'
playlists = spotify.get_playlists(search_term)

# 1. Uncomment below to see the returned data:
# pprint(playlists)

# 2. pandas doesn't gracefully handle heirarchal data (uncomment below to see what I mean)
# df = pd.DataFrame(tracks)
# df.head(3)

# 3. Format data and display in Pandas:
playlists = spotify.flatten_for_pandas(playlists)
df = pd.DataFrame(playlists).set_index('num')
df.head(8)
# Out:
#                          id  \
# num
# 1    37i9dQZF1DX5xie6IyJZjg
# 2    5Ic1drhGnSTeAcy2TbMd25
# 3    5Ct9qfDIQfjLVoVq3c9LBp
# 4    0OQfoFvigmVpXthFRwcxCa
# 5    4VR49RWW1TahUACYOVGujm
# 6    7aK2Ap6P3HRxHkC1kZvtGD
# 7    3nQXBhD9cdBOhED2RW5WmX
# 8    38T01DhVzS6Dj1u3QwNyw0
#
#                                                   name owner_display_name  \
# num
# 1                                    This Is: Cut Copy            Spotify
# 2                                       Cut Copy Radio          Meizi Mao
# 3     Cut Copy Greatest Hits (Haiku From Zero Out Now)        cutcopyband
# 4                                          Hipster Pop          samfreche
# 5    Cut Copy/Presets/Hot Chip/Friendly Fires/Pinba...  Jonah-kai Hancock
# 6                                             Cut Copy          Don Kasho
# 7                               Cut Copy Fabriclive.29      Bruno Genovez
# 8                                             Cut copy          Tomi Brow
#
#           owner_id
# num
# 1          spotify
# 2           meow22
# 3      cutcopyband
# 4        samfreche
# 5        122778472
# 6     kasho1234567
# 7       br.genovez
# 8    conibrowarski

# %% [markdown]
# ## 2. Ask the user which artist they'd like to listen to

# %%
# artist_num = input('What artist would you like to listen to (1-10)? ')
playlist_num = 2
playlist_index = int(playlist_num) - 1
selected_playlist = playlists[playlist_index]

tracks = spotify.get_tracks_by_playlist(selected_playlist['id'], simplify=True)
# pprint(tracks)
tracks = spotify.flatten_for_pandas(tracks)
df_tracks = pd.DataFrame(tracks).set_index('num')
df_tracks[['artist_name', 'name', 'album_name', 'album_image_url']]
# Out:
#                artist_name                                         name  \
# num
# 1                 Cut Copy                               Hearts On Fire
# 2                Chairlift                                 Polymorphing
# 3          LCD Soundsystem                           Dance Yrself Clean
# 4                   STRFKR                                    Basically
# 5                 Cut Copy                               Lights & Music
# 6               Washed Out                           Feel It All Around
# 7         William Onyeabor  Atomic Bomb - William Onyeabor vs. Hot Chip
# 8        Empire of the Sun                           Walking On A Dream
# 9                 Cut Copy                          January Tape Part 5
# 10             Small Black                                  No Stranger
# 11             Neon Indian                                  Polish Girl
# 12         LCD Soundsystem                              call the police
# 13                Poolside                                  And The Sea
# 14                Cut Copy                          January Tape Part 3
# 15              Washed Out                           It All Feels Right
# 16                 Caribou                                       Odessa
# 17             Neon Indian                              Deadbeat Summer
# 18         Crystal Castles                                     Vanished
# 19            Miami Horror                                    Sometimes
# 20            Wild Nothing                                       Shadow
# 21               The Knife                                   Heartbeats
# 22               Santigold                              Disparate Youth
# 23       Empire of the Sun                            We Are The People
# 24                   YACHT                Psychic City - Classixx Remix
# 25            Miami Horror               Real Slow Feat. Sarah Chernoff
# 26       Animal Collective                                     My Girls
# 27             Neon Indian                                        Annie
# 28                 Justice                                   D.A.N.C.E.
# 29                     M83                                Midnight City
# 30             Tame Impala                   The Less I Know The Better
# 31              Washed Out                                    Amor Fati
# 32                 Phoenix                                         1901
# 33    Peter Bjorn and John                                  Young Folks
# 34   The Whitest Boy Alive                                      Burning
# 35           Little Dragon                                 Ritual Union
# 36            Miami Horror                 I Look to You (feat. Kimbra)
# 37               Metronomy                                     The Look
# 38             Holy Ghost!                                   Wait & See
# 39                    MGMT                              Time to Pretend
# 40         Crystal Castles                                    Crimewave
# 41               Metronomy                                      The Bay
# 42                    MGMT                                Electric Feel
# 43             The Rapture                       How Deep Is Your Love?
# 44                Breakbot                Baby I'm Yours (feat. Irfane)
# 45       Empire of the Sun                                    Half Mast
# 46                Hot Chip                                       Flutes
# 47            Miami Horror                                  Moon Theory
# 48               Santigold                              Chasing Shadows
#
#                            album_name  \
# num
# 1                    In Ghost Colours
# 2                                Moth
# 3                   This Is Happening
# 4                        Vault Vol. 1
# 5                    In Ghost Colours
# 6                     Life Of Leisure
# 7                              What?!
# 8                  Walking On A Dream
# 9                        January Tape
# 10                   Limits of Desire
# 11                        Era Extraña
# 12   call the police / american dream
# 13                               Heat
# 14                       January Tape
# 15                           Paracosm
# 16                               Swim
# 17                     Psychic Chasms
# 18                    Crystal Castles
# 19                       Illumination
# 20                           Nocturne
# 21                          Deep Cuts
# 22          Master of My Make-Believe
# 23                 Walking On A Dream
# 24                       Psychic City
# 25               All Possible Futures
# 26         Merriweather Post Pavilion
# 27            Vega Intl. Night School
# 28                              Cross
# 29           Hurry up, We're Dreaming
# 30                           Currents
# 31                 Within and Without
# 32           Wolfgang Amadeus Phoenix
# 33                     Writer's Block
# 34                             Dreams
# 35                       Ritual Union
# 36                       Illumination
# 37                The English Riviera
# 38                        Holy Ghost!
# 39               Oracular Spectacular
# 40                    Crystal Castles
# 41                The English Riviera
# 42               Oracular Spectacular
# 43          In the Grace of Your Love
# 44                       By Your Side
# 45                 Walking On A Dream
# 46                       In Our Heads
# 47                       Illumination
# 48                           99 Cents
#
#                                        album_image_url
# num
# 1    https://i.scdn.co/image/0d1639fa2b10454ce03d28...
# 2    https://i.scdn.co/image/dbf3e22888de3a57d8e44c...
# 3    https://i.scdn.co/image/7c2ddcaf6e3aacc89a6470...
# 4    https://i.scdn.co/image/334cfc032781191f11313f...
# 5    https://i.scdn.co/image/0d1639fa2b10454ce03d28...
# 6    https://i.scdn.co/image/ec252b340909c2f3c4e77c...
# 7    https://i.scdn.co/image/f3443646e312bdbc80136c...
# 8    https://i.scdn.co/image/7d649cd7fe32c4224f49cf...
# 9    https://i.scdn.co/image/93e5ae0837a9e35baaf5d5...
# 10   https://i.scdn.co/image/0b5716b77ddae5cf503ba4...
# 11   https://i.scdn.co/image/e0979ea094fc59e98635c4...
# 12   https://i.scdn.co/image/27fe68224f8c19d18d1154...
# 13   https://i.scdn.co/image/5f7be4be204b4aed4d3499...
# 14   https://i.scdn.co/image/93e5ae0837a9e35baaf5d5...
# 15   https://i.scdn.co/image/99cb7892224f960a6b3424...
# 16   https://i.scdn.co/image/d847f22d4f5481febb1051...
# 17   https://i.scdn.co/image/7c6576d60df84191f8df2b...
# 18   https://i.scdn.co/image/ad48acaf205477bdc6af50...
# 19   https://i.scdn.co/image/e122b66063e5f93da2b7cd...
# 20   https://i.scdn.co/image/2a75809c19f8ee9578cbf0...
# 21   https://i.scdn.co/image/29047b2d5eb866b38f333d...
# 22   https://i.scdn.co/image/33dfdb9ff14477706fdbc6...
# 23   https://i.scdn.co/image/7d649cd7fe32c4224f49cf...
# 24   https://i.scdn.co/image/4c5684e7990e3b8e8dbdc3...
# 25   https://i.scdn.co/image/ed32b0404f7077962bfe61...
# 26   https://i.scdn.co/image/3e9632a9123d77f5b11d93...
# 27   https://i.scdn.co/image/aba7b557895a85cc1db4c5...
# 28   https://i.scdn.co/image/c60e559597aeadc85484f7...
# 29   https://i.scdn.co/image/2ccc3bd0455066a58b0008...
# 30   https://i.scdn.co/image/fed3593129c6254d7620b5...
# 31   https://i.scdn.co/image/1f82b4a1f76b69682a47f7...
# 32   https://i.scdn.co/image/b9de597614b9b5764c486c...
# 33   https://i.scdn.co/image/bee9575f9091971087aceb...
# 34   https://i.scdn.co/image/5b1b536476ad7f7375ecb3...
# 35   https://i.scdn.co/image/b25ba89cbacbe9cffeacad...
# 36   https://i.scdn.co/image/e122b66063e5f93da2b7cd...
# 37   https://i.scdn.co/image/04af8a8c03eb7ac8c0c9fd...
# 38   https://i.scdn.co/image/ff6bccff8753ea9659cffb...
# 39   https://i.scdn.co/image/b3794a3323bb0b55266b3e...
# 40   https://i.scdn.co/image/ad48acaf205477bdc6af50...
# 41   https://i.scdn.co/image/04af8a8c03eb7ac8c0c9fd...
# 42   https://i.scdn.co/image/b3794a3323bb0b55266b3e...
# 43   https://i.scdn.co/image/12e84faa04c6cadf52af2f...
# 44   https://i.scdn.co/image/8320492c9da9d03d285b35...
# 45   https://i.scdn.co/image/7d649cd7fe32c4224f49cf...
# 46   https://i.scdn.co/image/26b9af4550b79c3722a79f...
# 47   https://i.scdn.co/image/e122b66063e5f93da2b7cd...
# 48   https://i.scdn.co/image/cec0766bfdfd82cdd03714...

# %% [markdown]
# ## 3. Listen to playlist

# %%
playlist_player = spotify.get_playlist_player_html(selected_playlist['id'])
# print('This is what the HTML embed code looks like:\n', track_player)

display(HTML(playlist_player))
# Out:
#         <iframe src="https://open.spotify.com/embed/playlist/5Ic1drhGnSTeAcy2TbMd25"
#             width="400" height="280" frameborder="0" allowtransparency="true"
#             allow="encrypted-media">
#         </iframe>

# %% [markdown]
# ## 4. Get other playlists from this user

# %%
user_id = selected_playlist['owner_id']

print('Getting {user_id}\'s playlists...'.format(user_id=user_id))
playlists = spotify.get_playlists_by_user(user_id)
playlists = spotify.flatten_for_pandas(playlists)
df = pd.DataFrame(playlists)
df.head(8)
# Out:
# Getting meow22's playlists...
#                        id                name  num owner_display_name owner_id
# 0  1PN7VYg4y1xemsGX5CQ3of                2019    1          Meizi Mao   meow22
# 1  7hRZaowv84fHssdZhAqIns         White T Day    2          Meizi Mao   meow22
# 2  5zHK5Va6DmILYAk6T7Ugxz                2018    3          Meizi Mao   meow22
# 3  2uhAZILXSEM3OyqCkvdUm5    My Shazam Tracks    4          Meizi Mao   meow22
# 4  1mRiNsoXPzJRbM967qh8Hv           17 Autumn    5          Meizi Mao   meow22
# 5  6XbnaKMnWNS2fBj1ryEHkq              Comedy    6          Meizi Mao   meow22
# 6  5Ic1drhGnSTeAcy2TbMd25      Cut Copy Radio    7          Meizi Mao   meow22
# 7  0m6rj5a3MRlgftJfTbhyx5  Otis Redding Radio    8          Meizi Mao   meow22
